# %% [markdown]
# # Model Training: Fine-tuning MuRIL & TF-IDF Baseline
#
# This notebook covers:
# 1. Training the TF-IDF + Logistic Regression baseline
# 2. Fine-tuning Google's MuRIL (`google/muril-base-cased`) on local NVIDIA RTX 4000 Ada GPU
# 3. Generating confusion matrices and classification reports.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/intents.csv')
print(df['intent'].value_counts())
print(df['split'].value_counts())
