# %% [markdown]
# # Data Analysis & EDA: Chennai Transit Knowledge Base & Hindi NLU Corpus
#
# This notebook explores the station catalog, connectivity graph, alias distribution, and synthesized NLU intent dataset.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../data/processed/transport.db')
stations_df = pd.read_sql('SELECT * FROM stations', conn)
connections_df = pd.read_sql('SELECT * FROM connections', conn)
facilities_df = pd.read_sql('SELECT * FROM facilities', conn)

print(f'Total Stations: {len(stations_df)}')
print(f'Total Route Connections: {len(connections_df)}')
stations_df.head()
